# %% [markdown]
# # **ENTREGA DE PROBLEMAS 1**

# %% [markdown]
# Comenzamos ejecutando la siguiente instrucción con los paquetes de matemáticas que conocemos y vamos a utilizar.

# %%
# Si no tenemos algún paquete instalado:
# !pip install nombre_del_paquete

# %%
# Cargamos los paquetes que vamos a utilizar
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

# %% [markdown]
# ## **1. Gráfica de f(x)**
# Representa gráficamente la función $f(x)$ de la entrega, teniendo en cuenta las siguientes directrices:
#
#
#
# *   Tamaño de paso de la partición del eje $x$: $h=0.01$
# *   Márgenes del gráfico: $[-10,10]\times [-5,5]$
# *   Etiqueta a los ejes con $x$ e $y$.
# *   Pon un título representativo al gráfico

# %% [markdown]
# ## **2. Derivada de f(x)**
# Calcula la derivada de la función, $f'(x)$, y su derivada de orden 5, $f^{(5)}(x)$.

# %% [markdown]
# ## **3. Recta normal a f(x)**
# Calcula la recta normal a la función $f(x)$ en el punto $x=\pi$.

# %% [markdown]
# ## **4. Límites en el infinito**
#
# Calcula los límites en el infinito de $f(x)$.
#
# ¿Qué puedes decir sobre el comportamiento de la función en el infinito en base a los resultados obtenidos?

# %% [markdown]
# _Respuesta:_
